# %%
import pandas as pd
import re
from collections import Counter

# %%
keras = pd.read_csv('../Dataset/Keras_Posts.csv')
tensorflow = pd.read_csv('../Dataset/Tensorflow_Posts.csv')
pytorch = pd.read_csv('../Dataset/Pytorch_Posts.csv')

# Merge these dataframes
df = pd.concat([keras, tensorflow, pytorch], ignore_index=True)

# %%
# Extract tags and count occurrences
tags = [re.findall(r'<([^>]*)>', tag) for tag in df['Tags']]
tag_counts = Counter([tag for sublist in tags for tag in sublist])

# Sort tag counts in descending order
sorted_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

# Print sorted tag counts
for tag, count in sorted_counts:
    print(f"{tag}: {count}")
# Out:
# python: 2220
# pytorch: 1686
# tensorflow: 1304
# deep-learning: 417
# machine-learning: 324
# keras: 269
# tensorflow2.0: 231
# neural-network: 220
# tensor: 204
# python-3.x: 183
# conv-neural-network: 183
# numpy: 173
# huggingface-transformers: 118
# tensorflow-datasets: 113
# tensorflow.js: 92
# lstm: 78
# tensorflow-lite: 74
# gpu: 72
# torch: 72
# nlp: 69
# google-colaboratory: 67
# javascript: 63
# computer-vision: 58
# pytorch-lightning: 58
# torchvision: 49
# bert-language-model: 44
# object-detection: 43
# recurrent-neural-network: 41
# pytorch-dataloader: 41
# loss-function: 40
# pandas: 36
# arrays: 36
# c++: 35
# autograd: 35
# dataset: 34
# tensorflow-federated: 34
# image-processing: 33
# classification: 31
# scikit-learn: 29
# autoencoder: 28
# opencv: 27
# image: 27
# artificial-intelligence: 26
# docker: 26
# conda: 26
# transformer-model: 25
# object-detection-api: 25
# reinforcement-learning: 24
# android: 24
# resnet: 23
# gradient-descent: 23
# tensorboard: 23
# jupyter-notebook: 22
# anaconda: 22
# onnx: 22
# node.js: 22
# mnist: 21
# dataloader: 21
# optimization: 20
# nvidia: 20
# cuda: 20
# huggingface-tokenizers: 20
# indexing: 20
# tf.keras: 19
# google-cloud-platform: 19
# image-classification: 18
# generative-adversarial-network: 18
# libtorch: 18
# backpropagation: 17
# yolo: 16
# tensorflow-probability: 16
# fast-ai: 15
# r: 14
# cross-entropy: 14
# convolution: 14
# tpu: 14
# tensorflow-serving: 14
# matrix-multiplication: 14
# matrix: 13
# slice: 13
# concatenation: 13
# attention-model: 13
# image-segmentation: 13
# cudnn: 13
# pip: 13
# amazon-sagemaker: 13
# pytorch-geometric: 13
# transfer-learning: 12
# matplotlib: 12
# pycharm: 11
# training-data: 11
# metrics: 11
# word-embedding: 11
# apple-m1: 11
# jax: 11
# gradient: 11
# dropout: 11
# model: 10
# vgg-net: 10
# valueerror: 10
# semantic-segmentation: 10
# multidimensional-array: 10
# macos: 10
# tf.data.dataset: 10
# linear-regression: 10
# react-native: 10
# performance: 10
# quantization: 10
# vectorization: 10
# huggingface: 10
# time-series: 9
# data-augmentation: 9
# dataframe: 9
# csv: 9
# embedding: 9
# reshape: 9
# java: 9
# parallel-processing: 9
# data-science: 9
# yolov5: 9
# regression: 8
# multiclass-classification: 8
# typeerror: 8
# openai-gym: 8
# linux: 8
# gradienttape: 8
# tfrecord: 8
# automatic-differentiation: 8
# federated-learning: 8
# pickle: 8
# array-broadcasting: 8
# linear-algebra: 8
# list: 8
# keras-layer: 7
# feature-extraction: 7
# numpy-ndarray: 7
# multiprocessing: 7
# dqn: 7
# tokenize: 7
# ragged-tensors: 7
# reactjs: 7
# scipy: 7
# gpt-2: 7
# batch-normalization: 7
# onnxruntime: 7
# normalization: 7
# amazon-web-services: 7
# import: 7
# memory: 7
# oop: 7
# language-model: 7
# validation: 6
# prediction: 6
# coreml: 6
# layer: 6
# attributeerror: 6
# pre-trained-model: 6
# gridsearchcv: 6
# numpy-slicing: 6
# html: 6
# tensorflow-hub: 6
# visual-studio-code: 6
# windows: 6
# tfx: 6
# out-of-memory: 6
# ubuntu: 6
# kotlin: 6
# bazel: 6
# python-imaging-library: 6
# tensorflow2.x: 6
# c: 6
# faster-rcnn: 6
# image-augmentation: 6
# random: 6
# cmake: 6
# bounding-box: 6
# nan: 6
# vector: 6
# torchscript: 6
# multilabel-classification: 5
# softmax: 5
# coremltools: 5
# dimensions: 5
# text-classification: 5
# azure: 5
# activation-function: 5
# slurm: 5
# affinetransform: 5
# random-seed: 5
# deeplab: 5
# albumentations: 5
# dockerfile: 5
# sentiment-analysis: 5
# fastapi: 5
# named-entity-recognition: 5
# memory-leaks: 5
# torchtext: 5
# iterator: 5
# torchaudio: 5
# max-pooling: 4
# word2vec: 4
# error-handling: 4
# seq2seq: 4
# sequential: 4
# loss: 4
# plot: 4
# loops: 4
# conv1d: 4
# dictionary: 4
# chatbot: 4
# tensorrt: 4
# ragged: 4
# arm: 4
# typescript: 4
# protocol-buffers: 4
# kaggle: 4
# autodiff: 4
# jupyter-lab: 4
# tensorflowjs-converter: 4
# tensorflow-model-garden: 4
# distributed-computing: 4
# derivative: 4
# miniconda: 4
# json: 4
# filter: 4
# module: 4
# segmentation-fault: 4
# sorting: 4
# multithreading: 4
# distributed: 4
# for-loop: 4
# streamlit: 4
# regularized: 4
# precision: 4
# nvcc: 4
# speech-recognition: 4
# class: 4
# stable-baselines: 4
# gated-recurrent-unit: 4
# detectron: 4
# debugging: 4
# skorch: 4
# numpy-einsum: 4
# parameters: 4
# ensemble-learning: 3
# precision-recall: 3
# c#: 3
# siamese-network: 3
# rgb: 3
# runtime-error: 3
# one-hot-encoding: 3
# k-fold: 3
# relu: 3
# mlp: 3
# databricks: 3
# efficientnet: 3
# ocr: 3
# h5py: 3
# roberta-language-model: 3
# generator: 3
# ubuntu-18.04: 3
# file: 3
# google-cloud-tpu: 3
# flutter: 3
# dart: 3
# driver: 3
# angular: 3
# google-mlkit: 3
# data-preprocessing: 3
# tensorflow1.15: 3
# time: 3
# arduino: 3
# esp32: 3
# predict: 3
# metal: 3
# google-chrome-extension: 3
# math: 3
# pipeline: 3
# bodypix: 3
# docker-compose: 3
# tensorflow-data-validation: 3
# librosa: 3
# tf-agent: 3
# importerror: 3
# python-3.7: 3
# ubuntu-20.04: 3
# intel: 3
# python-2.7: 3
# conditional-statements: 3
# bayesian: 3
# sigmoid: 3
# deconvolution: 3
# raspberry-pi: 3
# heroku: 3
# matrix-indexing: 3
# floating-point: 3
# rounding: 3
# graph-neural-network: 3
# forecasting: 3
# string: 3
# coco: 3
# multi-gpu: 3
# scikit-image: 3
# django: 3
# dcgan: 3
# sgd: 3
# audio: 3
# knn: 3
# fft: 3
# logistic-regression: 3
# python-multiprocessing: 3
# graph: 3
# interpolation: 3
# langchain: 3
# jit: 3
# inference: 3
# dtype: 3
# amazon-ec2: 3
# learning-rate: 3
# networkx: 3
# mse: 3
# google-cloud-vertex-ai: 3
# flatten: 2
# similarity: 2
# functional-api: 2
# keras-tuner: 2
# encoding: 2
# swift: 2
# wandb: 2
# azure-databricks: 2
# .net: 2
# python-class: 2
# tkinter: 2
# grayscale: 2
# auc: 2
# cross-validation: 2
# opencv-python: 2
# model-fitting: 2
# keras-rl: 2
# grid-search: 2
# data-generation: 2
# genetic-algorithm: 2
# image-recognition: 2
# early-stopping: 2
# deep-residual-networks: 2
# evaluation: 2
# instance: 2
# oserror: 2
# yolov4: 2
# nodes: 2
# signal-processing: 2
# nvidia-jetson: 2
# lookup: 2
# memory-management: 2
# tensorly: 2
# mobilenet: 2
# face-api: 2
# ipu: 2
# sentence-similarity: 2
# rasa-nlu: 2
# rasa: 2
# encoder-decoder: 2
# ios: 2
# bash: 2
# video: 2
# joblib: 2
# tf2onnx: 2
# eager-execution: 2
# shap: 2
# shapes: 2
# pose-estimation: 2
# npm: 2
# android-studio: 2
# cluster-computing: 2
# grpc: 2
# compiler-errors: 2
# convergence: 2
# image-rotation: 2
# regex: 2
# if-statement: 2
# input: 2
# output: 2
# openvino: 2
# roberta: 2
# installation: 2
# single-shot-detector: 2
# windows-10: 2
# intel-lpot: 2
# ctc: 2
# c-api: 2
# warnings: 2
# api: 2
# data-pipeline: 2
# openai-api: 2
# gcloud: 2
# kubernetes: 2
# nvidia-docker: 2
# checkpoint: 2
# normal-distribution: 2
# simpletransformers: 2
# google-cloud-ml: 2
# image-resizing: 2
# tensorflow-agents: 2
# mamba: 2
# gensim: 2
# types: 2
# unet-neural-network: 2
# serialization: 2
# tfjs-node: 2
# vision: 2
# type-conversion: 2
# apache-beam: 2
# server: 2
# uvicorn: 2
# google-cloud-dataflow: 2
# ray: 2
# confusion-matrix: 2
# mean-square-error: 2
# ssh: 2
# centos: 2
# gaussian-process: 2
# spacy: 2
# padding: 2
# split: 2
# darknet: 2
# probability: 2
# yaml: 2
# intel-mkl: 2
# cpu: 2
# roboflow: 2
# gcp-ai-platform-notebook: 2
# image-preprocessing: 2
# machine-translation: 2
# danfojs: 2
# casting: 2
# q-learning: 2
# computation-graph: 2
# mask: 2
# allennlp: 2
# tensorboardx: 2
# reproducible-research: 2
# fairseq: 2
# lambda: 2
# stable-diffusion: 2
# mean: 2
# comparison: 2
# reticulate: 2
# matlab: 2
# numba: 2
# testing: 2
# storage: 2
# flask: 2
# batchsize: 2
# custom-training: 2
# self: 2
# pruning: 2
# retinanet: 2
# sentence-transformers: 2
# intel-pytorch: 2
# view: 2
# higher: 2
# huggingface-datasets: 2
# torchserve: 2
# transformation: 2
# dynamic-programming: 2
# in-place: 2
# iris-dataset: 2
# densenet: 2
# adaptive-threshold: 1
# modulenotfounderror: 1
# image-generation: 1
# dashboard: 1
# plotly-dash: 1
# online-machine-learning: 1
# mlxtend: 1
# sequence: 1
# missing-data: 1
# style-transfer: 1
# masking: 1
# multiple-input: 1
# handwriting-recognition: 1
# weighted: 1
# auto-keras: 1
# euclidean-distance: 1
# channel: 1
# multi-layer: 1
# coefficients: 1
# pool: 1
# weak-references: 1
# plaidml: 1
# spyder: 1
# lstm-stateful: 1
# tesseract: 1
# python-tesseract: 1
# load: 1
# unzip: 1
# hdf5: 1
# cjk: 1
# train-test-split: 1
# mlmodel: 1
# sequence-to-sequence: 1
# subplot: 1
# temporal: 1
# suppress-warnings: 1
# suppressmessage: 1
# machine-learning-model: 1
# azure-blob-storage: 1
# virtual-machine: 1
# distutils: 1
# configuration: 1
# directory: 1
# gradle: 1
# pylint: 1
# pylance: 1
# theano: 1
# blas: 1
# google-meet: 1
# google-dl-platform: 1
# ml.net: 1
# object: 1
# batch-processing: 1
# detection: 1
# automl: 1
# hyperparameters: 1
# decorator: 1
# centos7: 1
# web-worker: 1
# tsconfig: 1
# requirements.txt: 1
# teachable-machine: 1
# hashtable: 1
# tcmalloc: 1
# startup: 1
# rtx: 1
# translation: 1
# opennmt: 1
# dependencies: 1
# proto: 1
# protobuf-python: 1
# feed-forward: 1
# sklearn-pandas: 1
# dask: 1
# dask-distributed: 1
# protoc: 1
# callback: 1
# cielab: 1
# activation: 1
# summary: 1
# webpack: 1
# electron: 1
# webgl: 1
# vite: 1
# alpine-linux: 1
# triangular: 1
# g++: 1
# embedded-linux: 1
# react-native-vision-camera: 1
# large-data: 1
# wav: 1
# statistics: 1
# quantile-regression: 1
# collections: 1
# ordereddictionary: 1
# quantization-aware-training: 1
# exponential: 1
# gdb: 1
# cuda-gdb: 1
# netlify: 1
# boto3: 1
# apache-spark: 1
# pyspark: 1
# apple-silicon: 1
# anomaly-detection: 1
# imbalanced-data: 1
# multicollinearity: 1
# face-recognition: 1
# popart: 1
# poplar: 1
# ml-studio: 1
# flatbuffers: 1
# google-oauth: 1
# terraform: 1
# amazon-rds: 1
# amazon-aurora: 1
# rllib: 1
# tensorflow-c++: 1
# bit-manipulation: 1
# seaborn: 1
# heatmap: 1
# zlib: 1
# bayesian-deep-learning: 1
# language-translation: 1
# google-ai-platform: 1
# patch: 1
# multiplication: 1
# google-cloud-ai-platform-pipelines: 1
# google-kubernetes-engine: 1
# tritonserver: 1
# cmsis: 1
# firefox-addon: 1
# metadata: 1
# blenderbot: 1
# wget: 1
# color-space: 1
# tensorflow-io: 1
# set: 1
# elmo: 1
# google-cloud-ai: 1
# hpc: 1
# real-time: 1
# tensorflow-xla: 1
# makefile: 1
# image-masking: 1
# path: 1
# 7zip: 1
# xcopy: 1
# adb: 1
# gdal: 1
# lib: 1
# fasttext: 1
# arduino-esp32: 1
# azure-functions: 1
# replit: 1
# segformer: 1
# prefetch: 1
# multinomial: 1
# pearson-correlation: 1
# group-by: 1
# hashmap: 1
# self-attention: 1
# paddleocr: 1
# mambaforge: 1
# android-ndk: 1
# curve-fitting: 1
# tiff: 1
# operating-system: 1
# hidden-files: 1
# hex: 1
# physics: 1
# velocity: 1
# ddpg: 1
# taylor-series: 1
# sudo: 1
# go: 1
# buf: 1
# interrupt: 1
# arm64: 1
# xcode: 1
# core-audio: 1
# pepper: 1
# google-cloud-storage: 1
# google-coral: 1
# edge-tpu: 1
# powershell: 1
# rest: 1
# apache-beam-io: 1
# sigkill: 1
# post-processing: 1
# pca: 1
# function: 1
# return-value: 1
# macbookpro-touch-bar: 1
# qsub: 1
# migration: 1
# jquery: 1
# python-3.6: 1
# computer-science: 1
# expo: 1
# ode: 1
# key: 1
# jq: 1
# discord.js: 1
# adversarial-machines: 1
# nlg: 1
# nonlinear-optimization: 1
# nltk: 1
# eigenvalue: 1
# eigenvector: 1
# ml5.js: 1
# asynchronous: 1
# sanic: 1
# labelimg: 1
# datetime: 1
# binary-image: 1
# colormap: 1
# google-cloud-automl: 1
# paramiko: 1
# svm: 1
# pydicom: 1
# medical-imaging: 1
# lookup-tables: 1
# numerical-integration: 1
# rasa-sdk: 1
# command-line: 1
# variables: 1
# gpflow: 1
# text-to-speech: 1
# gesture-recognition: 1
# concurrent.futures: 1
# eigen: 1
# yocto: 1
# coqui: 1
# arduino-nano: 1
# xor: 1
# bitwise-xor: 1
# pose: 1
# ajax: 1
# imageai: 1
# xgboost: 1
# mediapipe: 1
# imblearn: 1
# smote: 1
# multiple-gpu: 1
# overfitting-underfitting: 1
# reduce: 1
# xserver: 1
# webcam: 1
# quantum-computing: 1
# tensorflow-quantum: 1
# cirq: 1
# google-bigquery: 1
# johnsnowlabs-spark-nlp: 1
# shuffle: 1
# distilbert: 1
# webassembly: 1
# random-forest: 1
# nvidia-jetson-nano: 1
# imagedata: 1
# qualcomm: 1
# snpe: 1
# sparse-matrix: 1
# character-encoding: 1
# github: 1
# angularjs: 1
# ionic-framework: 1
# jupyter: 1
# intel-tensorflow: 1
# trax: 1
# tensorflow-gradient: 1
# non-maximum-suppression: 1
# google-codelab: 1
# tensorflow2: 1
# axis: 1
# dot-product: 1
# joi: 1
# ngrok: 1
# alias: 1
# cluster-analysis: 1
# encoder: 1
# dimensionality-reduction: 1
# autocomplete: 1
# code-completion: 1
# powerpc: 1
# keyerror: 1
# pattern-recognition: 1
# tqdm: 1
# gunicorn: 1
# scalar: 1
# syntax: 1
# difference: 1
# ddp: 1
# dll: 1
# generative-art: 1
# opencl: 1
# filtering: 1
# diagonal: 1
# profiler: 1
# chatgpt-api: 1
# uncertainty: 1
# top-n: 1
# celery: 1
# constructor: 1
# subclass: 1
# gaussianblur: 1
# zarr: 1
# apex: 1
# shared-memory: 1
# index-error: 1
# duplicates: 1
# unique: 1
# asgi: 1
# mongodb: 1
# amd: 1
# state-dict: 1
# memory-profiling: 1
# ssl: 1
# einops: 1
# complex-numbers: 1
# determinants: 1
# bidirectional: 1
# cosine-similarity: 1
# type-hinting: 1
# google-cloud-functions: 1
# stateless: 1
# min: 1
# sign: 1
# absolute-value: 1
# caffe2: 1
# registration: 1
# terminology: 1
# mmap: 1
# variance: 1
# customization: 1
# weighted-average: 1
# inverse: 1
# super: 1
# pytorch-distributions: 1
# geometry: 1
# cuda-streams: 1
# object-tracking: 1
# sockets: 1
# azure-machine-learning-service: 1
# unfold: 1
# naming-conventions: 1
# cross-correlation: 1
# advanced-indexing: 1
# mini-batch: 1
# environment-variables: 1
# u8darts: 1
# ram: 1
# python-typing: 1
# google-cloud-run: 1
# iteration: 1
# perceptron: 1
# memory-efficient: 1
# processing-efficiency: 1
# virtualenv: 1
# airflow: 1
# google-publisher-tag: 1
# gpt-3: 1
# wsl-2: 1
# histogram: 1
# bin: 1
# undirected-graph: 1
# dlib: 1
# intellij-idea: 1
# stochastic-gradient: 1
# arguments: 1
# numpy-indexing: 1
# bigdata: 1
# utf-8: 1
# utf: 1
# save: 1
# aws-lambda: 1
# kedro: 1
# stacking-context: 1
# nameerror: 1
# windows-11: 1
# contourf: 1
# data-manipulation: 1
# six: 1
# ipython: 1
# pairwise: 1
# zero-padding: 1
# union: 1
# differentiation: 1
# image-formats: 1
# recommendation-engine: 1
# boolean: 1
# linker-errors: 1
# argmax: 1
# exception: 1
# iterable: 1
# initialization: 1
# eval: 1
# racing: 1
# unsupervised-learning: 1
# spacy-transformers: 1
# yolov7: 1
# intel-python: 1
# bilstm: 1
# numpy-memmap: 1
# standard-error: 1
# hessian-matrix: 1
# einsum: 1
# matmul: 1
# gpytorch: 1
# refactoring: 1
# easyocr: 1
# runtime: 1
# dnn9: 1
# distance: 1
# cpu-usage: 1
# facenet: 1
# mobile: 1
# printing: 1
# nvidia-smi: 1
# vram: 1
# std: 1
# image-size: 1
# motion-blur: 1
# robustness: 1
# noise: 1
# export: 1
# pycocotools: 1
# satellite-image: 1
# pyro.ai: 1
# cmd: 1
# terminal: 1
# batch-file: 1
# internal-server-error: 1
# illegalaccessexception: 1
# pytorch3d: 1
# stride: 1
# python-requests: 1
# julia: 1
# flux.jl: 1
# python-poetry: 1
# cupy: 1
# neuraxle: 1
# horovod: 1
# google-vision: 1
# tsne: 1
# visualization: 1
# package: 1
# image-compression: 1
# broadcast: 1
# data-visualization: 1
# fork: 1
# distribution: 1
# gcc: 1
# clang: 1
# object-recognition: 1
# python-logging: 1
# imagenet: 1
# 3d: 1
# pyinstaller: 1
# logging: 1
# mxnet: 1
# matrix-factorization: 1
# symbol-not-found: 1
# reverse: 1
# ssim: 1
# monk: 1
# resuming-training: 1
# mathematical-optimization: 1
# size: 1
# multi-level: 1
# file-read: 1
# equality: 1
# pytest: 1
# normalize: 1
# svd: 1
# orthogonal: 1
# numerical-stability: 1
# multihead-attention: 1
# gaussian-mixture-model: 1
# meta-learning: 1
# adversarial-attack: 1
# gradio: 1
# gnn: 1
# data-conversion: 1
# edges: 1
# batchnorm: 1
# tensordot: 1
# rbm: 1
# caffe: 1
# bayesian-networks: 1
# pgmpy: 1
# compression: 1
# indices: 1
# pycaret: 1
# c++11: 1
# fortran: 1
# perplexity: 1
# modelsummary: 1
# django-models: 1
# django-views: 1

# %%
# Give CSV for the Sorted Tag Counts
df = pd.DataFrame(sorted_counts, columns=['Tag', 'Count'])
df.to_csv('../Dataset/Tag_Counts.csv', index=False)

# %% [markdown]
# ## Taxonomy
#
# * Model
#     * Missing/Redundant/Wrong Layer
#     * Layer Properties
#     * Activation Function
# * Tensor & Inputs
#     * Wrong Tensor Shape
#     * Wrong Input
# * Training
#     * Hyperparameters
#     * Loss Function
#     * Preprocessing of Training Data
#     * Optimiser
#     * Training Data Quality
#     * Training Process
# * GPU
# * API

# %% [markdown]
# ### Types of Networks covered
#
# * Convolutional Neural Network (CNN)
# * Long Short-Term Memory (LSTM)
# * Recurrent Neural Network (RNN)
# * Generative Adversarial Network (GAN)
# * Autoencoder
# * Siamese Network
# * Graph Neural Network (GNN)
# * Multilayer Perceptron (MLP)
# * Self-Attention

# %% [markdown]
# ### Relevant Tags for Different Types of Bugs
#
# * Tensor
# * NumPy
# * GPU
# * Loss Function
# * Dataset
# * Arrays
# * Training Data
# * NVIDIA
# * CUDA
# * Optimization
# * Cross Entropy
# * Backpropogation
# * Model
# * Gradient
# * Data Augmentation
# * Loss
# * Reshape
# * Activation Function
# * Performance
# * Dropout
# * Type Error
# * Runtime Error
# * Layer
# * Memory
# * Out of Memory
# * Normalization
# * Dimensions
# * Learning Rate
# * CPU
# * NaN
# * Memory Leaks
# * Hyperparameters
# * Segmentation Fault
# * Initialization
# * Imbalanced Data

# %% [markdown]
# ### Bugs and their Tags
#
# Model: Gradient, Layer, Model, Activation Function
#
# Tensor & Input: Tensor
#
# Training: Loss Function, Training Data, Optimization, Cross Entropy, Backpropagation, Loss, Data Augmentation, Performance, Dropout, Learning Rate, Hyperparameters, Initialization, Imbalanced Data, Runtime Error, Segmentation Fault, NaN
#
# GPU: GPU, NVIDIA, CUDA, Out of Memory, Memory Leaks
#
# API: Type Error, Value Error, Attribute Error, Import Error, Compiler Error, Syntax Error, Module Not Found Error

# %%
keras = pd.read_csv('../Dataset/Keras_Posts.csv')
tensorflow = pd.read_csv('../Dataset/Tensorflow_Posts.csv')
pytorch = pd.read_csv('../Dataset/Pytorch_Posts.csv')

# Merge these dataframes
df = pd.concat([keras, tensorflow, pytorch], ignore_index=True)

# Remove <> from the tags
df['Spaced_Tags'] = df['Tags'].str.replace(r'<', ' ')
df['Spaced_Tags'] = df['Tags'].str.replace(r'>', ' ')

# Drop Unnamed: 3 column and rename Unnamed: 0 to links
df.drop(['Unnamed: 4'], axis=1, inplace=True)
df.rename(columns={'Unnamed: 0': 'Links'}, inplace=True)

# %%
# Create a new column ID
df['Id'] = df.index
for index, row in df.iterrows():
    df.at[index, 'Id'] = df.at[index, 'QuestionLink'].split('/')[-1]

# %%
def get_posts(tags, df):
    condition = False
    for tag in tags:
        condition = condition | df['Spaced_Tags'].str.contains(r'\b{}\b'.format(tag))
    return df[condition]

model_bugs = get_posts(['layer', 'model', 'activation-function'], df)
tensor_bugs = get_posts(['tensor'], df)
training_bugs = get_posts(['loss-function', 'training-data', 'optimization', 'loss', 'data-augmentation', 'performance', 'learning-rate', 'hyperparameters', 'initialization', 'imbalanced-data', 'nan'], df)
gpu_bugs = get_posts(['gpu', 'nvidia', 'cuda'], df)
api_bugs = get_posts(['typeerror', 'valueerror', 'attributeerror', 'importerror', 'compilererrors', 'syntaxerror', 'modulenotfounderror'], df)

# %%
print (f'Number of Model Bugs: {len(model_bugs)}')
print (f'Number of Tensor & Input Bugs: {len(tensor_bugs)}')
print (f'Number of Training Bugs: {len(training_bugs)}')
print (f'Number of GPU Bugs: {len(gpu_bugs)}')
print (f'Number of API Bugs: {len(api_bugs)}')
# Out:
# Number of Model Bugs: 123
# Number of Tensor & Input Bugs: 204
# Number of Training Bugs: 103
# Number of GPU Bugs: 110
# Number of API Bugs: 28

# %%
# Common posts between model_bugs and tensor_input
model_tensor = pd.merge(model_bugs, tensor_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between model_bugs and training_bugs
model_training = pd.merge(model_bugs, training_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between model_bugs and gpu_bugs
model_gpu = pd.merge(model_bugs, gpu_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between model_bugs and api_bugs
model_api = pd.merge(model_bugs, api_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between tensor_bugs and training_bugs
tensor_training = pd.merge(tensor_bugs, training_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between tensor_bugs and gpu_bugs
tensor_gpu = pd.merge(tensor_bugs, gpu_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between tensor_bugs and api_bugs
tensor_api = pd.merge(tensor_bugs, api_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between training_bugs and gpu_bugs
training_gpu = pd.merge(training_bugs, gpu_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between training_bugs and api_bugs
training_api = pd.merge(training_bugs, api_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

# Common posts between gpu_bugs and api_bugs
gpu_api = pd.merge(gpu_bugs, api_bugs, how='inner', on=['QuestionLink', 'Title', 'Score', 'Tags', 'Spaced_Tags', 'Id'])

print (f'Number of Common Posts between Model & Tensor: {len(model_tensor)}')
print (f'Number of Common Posts between Model & Training: {len(model_training)}')
print (f'Number of Common Posts between Model & GPU: {len(model_gpu)}')
print (f'Number of Common Posts between Model & API: {len(model_api)}')
print (f'Number of Common Posts between Tensor & Training: {len(tensor_training)}')
print (f'Number of Common Posts between Tensor & GPU: {len(tensor_gpu)}')
print (f'Number of Common Posts between Tensor & API: {len(tensor_api)}')
print (f'Number of Common Posts between Training & GPU: {len(training_gpu)}')
print (f'Number of Common Posts between Training & API: {len(training_api)}')
print (f'Number of Common Posts between GPU & API: {len(gpu_api)}')
# Out:
# Number of Common Posts between Model & Tensor: 5
# Number of Common Posts between Model & Training: 2
# Number of Common Posts between Model & GPU: 2
# Number of Common Posts between Model & API: 1
# Number of Common Posts between Tensor & Training: 1
# Number of Common Posts between Tensor & GPU: 5
# Number of Common Posts between Tensor & API: 0
# Number of Common Posts between Training & GPU: 2
# Number of Common Posts between Training & API: 3
# Number of Common Posts between GPU & API: 0

# %%
# Merge all the dataframes
model_bugs['Type'] = 'model'
tensor_bugs['Type'] = 'tensor'
training_bugs['Type'] = 'training'
gpu_bugs['Type'] = 'gpu'
api_bugs['Type'] = 'api'

df = pd.concat([model_bugs, tensor_bugs, training_bugs, gpu_bugs, api_bugs], ignore_index=True)
df.drop_duplicates(subset=['Id'], keep=False, inplace=True)
# df.to_csv('../Dataset/DL_Bugs_Complete.csv', index=False)
# Out:
# C:\Users\Mehil Shah\AppData\Local\Temp\ipykernel_18304\1035452258.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   model_bugs['Type'] = 'model'
# C:\Users\Mehil Shah\AppData\Local\Temp\ipykernel_18304\1035452258.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   tensor_bugs['Type'] = 'tensor'
# C:\Users\Mehil Shah\AppData\Local\Temp\ipykernel_18304\1035452258.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   training_bugs['Type'] = 'training'
# C:\Users\Mehil Shah\AppData\Local\Temp\ipykernel_18304\1035452258.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   gpu_bugs['Type'] = 'gpu'
# C:\Users\Mehil Shah\AppData\Local\Temp\ipykernel_18304\1035452258.py:6: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   api_bugs['Type'] = 'api'

# %%
model_bugs = get_posts(['layer', 'model', 'activation-function'], df)
tensor_bugs = get_posts(['tensor'], df)
training_bugs = get_posts(['loss-function', 'training-data', 'optimization', 'loss', 'data-augmentation', 'performance', 'learning-rate', 'hyperparameters', 'initialization', 'imbalanced-data', 'nan'], df)
gpu_bugs = get_posts(['gpu', 'nvidia', 'cuda'], df)
api_bugs = get_posts(['typeerror', 'valueerror', 'attributeerror', 'importerror', 'compilererrors', 'syntaxerror', 'modulenotfounderror'], df)

# %%
print (f'Number of Unique Model Bugs: {len(model_bugs)}')
print (f'Number of Unique Tensor & Input Bugs: {len(tensor_bugs)}')
print (f'Number of Unique Training Bugs: {len(training_bugs)}')
print (f'Number of Unique GPU Bugs: {len(gpu_bugs)}')
print (f'Number of Unique API Bugs: {len(api_bugs)}')
# Out:
# Number of Unique Model Bugs: 113
# Number of Unique Tensor & Input Bugs: 193
# Number of Unique Training Bugs: 95
# Number of Unique GPU Bugs: 101
# Number of Unique API Bugs: 24

# %%
total_len = len(model_bugs) + len(tensor_bugs) + len(training_bugs) + len(gpu_bugs) + len(api_bugs)
print (f'Total Number of Unique Bugs: {total_len}')
print (f'Percentage of Model Bugs: {round((len(model_bugs)/total_len)*100, 2)}%')
print (f'Percentage of Tensor & Input Bugs: {round((len(tensor_bugs)/total_len)*100, 2)}%')
print (f'Percentage of Training Bugs: {round((len(training_bugs)/total_len)*100, 2)}%')
print (f'Percentage of GPU Bugs: {round((len(gpu_bugs)/total_len)*100, 2)}%')
print (f'Percentage of API Bugs: {round((len(api_bugs)/total_len)*100, 2)}%')
# Out:
# Total Number of Unique Bugs: 526
# Percentage of Model Bugs: 21.48%
# Percentage of Tensor & Input Bugs: 36.69%
# Percentage of Training Bugs: 18.06%
# Percentage of GPU Bugs: 19.2%
# Percentage of API Bugs: 4.56%

# %%
# Total: 250 Bugs, derive  number of model bugs, tensor bugs, training bugs and gpu bugs, and api bugs
model_bugs = model_bugs.sample(n = int(250 * 21.48 // 100), random_state = 42)
tensor_bugs = tensor_bugs.sample(n = int(250 * 36.69) // 100, random_state = 42)
training_bugs = training_bugs.sample(n = int(250 * 18.06) // 100, random_state = 42)
gpu_bugs = gpu_bugs.sample(n = int(250 * 19.2) // 100, random_state = 42)
api_bugs = api_bugs.sample(n = int(250 * 4.56) // 100, random_state = 42)

model_bugs['Type'] = 'model'
tensor_bugs['Type'] = 'tensor'
training_bugs['Type'] = 'training'
gpu_bugs['Type'] = 'gpu'
api_bugs['Type'] = 'api'

# Merge all the dataframes
df = pd.concat([model_bugs, tensor_bugs, training_bugs, gpu_bugs, api_bugs], ignore_index=True)
df = df.drop(['Spaced_Tags'], axis=1)

# %%
# Extract tags and count occurrences
tags = [re.findall(r'<([^>]*)>', tag) for tag in df['Tags']]
tag_counts = Counter([tag for sublist in tags for tag in sublist])

# Sort tag counts in descending order
sorted_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

# Print sorted tag counts
for tag, count in sorted_counts:
    print(f"{tag}: {count}")
# Out:
# python: 159
# pytorch: 138
# tensor: 91
# tensorflow: 86
# gpu: 34
# deep-learning: 28
# bert-language-model: 20
# keras: 18
# machine-learning: 18
# loss-function: 18
# neural-network: 17
# tensorflow2.0: 14
# numpy: 12
# nlp: 11
# huggingface-transformers: 10
# transformer-model: 10
# torch: 10
# conv-neural-network: 10
# cuda: 9
# attention-model: 8
# python-3.x: 8
# optimization: 8
# data-augmentation: 7
# nvidia: 7
# huggingface-tokenizers: 5
# performance: 5
# tensorflow.js: 4
# model: 4
# arrays: 4
# typeerror: 4
# matrix: 3
# pre-trained-model: 3
# multidimensional-array: 3
# roberta-language-model: 3
# keras-layer: 3
# language-model: 3
# loops: 3
# tensorflow-datasets: 3
# matrix-multiplication: 3
# autoencoder: 3
# sorting: 3
# image-processing: 3
# indexing: 3
# javascript: 3
# nan: 3
# activation-function: 2
# tf.keras: 2
# tpu: 2
# tensorflow-model-garden: 2
# gpt-2: 2
# pandas: 2
# object-detection: 2
# google-colaboratory: 2
# vectorization: 2
# list: 2
# concatenation: 2
# array-broadcasting: 2
# node.js: 2
# pytorch-lightning: 2
# validation: 2
# cross-entropy: 2
# training-data: 2
# mse: 2
# artificial-intelligence: 2
# anaconda: 2
# cudnn: 2
# tensorrt: 2
# nvidia-jetson: 2
# distributed-computing: 2
# out-of-memory: 2
# google-cloud-platform: 2
# attributeerror: 2
# importerror: 2
# valueerror: 2
# word-embedding: 1
# multi-layer: 1
# sequence-to-sequence: 1
# layer: 1
# predict: 1
# sentiment-analysis: 1
# densenet: 1
# embedding: 1
# resnet: 1
# tokenize: 1
# caffe: 1
# android: 1
# tensorflow-lite: 1
# amazon-ec2: 1
# save: 1
# machine-learning-model: 1
# deeplab: 1
# model-fitting: 1
# text-classification: 1
# object-detection-api: 1
# self-attention: 1
# difference: 1
# normalization: 1
# mnist: 1
# tensorflow2.x: 1
# reduce: 1
# casting: 1
# metrics: 1
# pearson-correlation: 1
# image: 1
# shapes: 1
# advanced-indexing: 1
# mask: 1
# matrix-indexing: 1
# reverse: 1
# multiplication: 1
# linear-algebra: 1
# reshape: 1
# flutter: 1
# dart: 1
# tensordot: 1
# type-conversion: 1
# rounding: 1
# motion-blur: 1
# max-pooling: 1
# ragged: 1
# numpy-einsum: 1
# memory: 1
# intel: 1
# intel-python: 1
# intel-pytorch: 1
# data-preprocessing: 1
# image-masking: 1
# faster-rcnn: 1
# probability: 1
# hyperparameters: 1
# transfer-learning: 1
# recurrent-neural-network: 1
# jax: 1
# gradient: 1
# gradient-descent: 1
# conv1d: 1
# tensorboard: 1
# rasa-nlu: 1
# rasa: 1
# plot: 1
# mean-square-error: 1
# affinetransform: 1
# torchvision: 1
# loss: 1
# coefficients: 1
# for-loop: 1
# graph: 1
# runtime: 1
# intel-mkl: 1
# speech-recognition: 1
# data-generation: 1
# nonlinear-optimization: 1
# sgd: 1
# apex: 1
# conda: 1
# installation: 1
# multi-gpu: 1
# ubuntu: 1
# tfx: 1
# tritonserver: 1
# lstm: 1
# time: 1
# startup: 1
# rtx: 1
# python-poetry: 1
# onnx: 1
# linux: 1
# docker: 1
# c++: 1
# libtorch: 1
# jupyter-notebook: 1
# blas: 1
# dcgan: 1
# multiple-gpu: 1
# lib: 1
# hpc: 1
# slurm: 1
# google-dl-platform: 1
# cuda-streams: 1
# gcc: 1
# nvcc: 1
# string: 1
# modulenotfounderror: 1
# fast-ai: 1
# generative-adversarial-network: 1
# pycharm: 1
# windows-10: 1
# chatbot: 1
# relu: 1
# oop: 1
# error-handling: 1
# efficientnet: 1

# %%
df.head()
# Out:
#                                    QuestionLink  \
# 0  https://stackoverflow.com/questions/72775559
# 1  https://stackoverflow.com/questions/65228352
# 2  https://stackoverflow.com/questions/67863454
# 3  https://stackoverflow.com/questions/73102413
# 4  https://stackoverflow.com/questions/69704467
#
#                                                Title  Score  \
# 0  resize_token_embeddings on the a pertrained mo...      2
# 1  Matrix inverse approximation with keras dense ...      2
# 2  Custom Activation function in tensorflow with ...      1
# 3  Loading a modified pretrained model using stri...      2
# 4  Concatenate layer shape error in sequence2sequ...      1
#
#                                                 Tags        Id   Type
# 0  <pytorch><huggingface-transformers><bert-langu...  72775559  model
# 1  <python><matrix><keras><neural-network><multi-...  65228352  model
# 2   <tensorflow><tensorflow2.0><activation-function>  67863454  model
# 3  <python><deep-learning><pytorch><pre-trained-m...  73102413  model
# 4  <python><keras><nlp><attention-model><sequence...  69704467  model

# %%
df.to_csv('../Dataset/DL_Bugs.csv', index=False)

# %% [markdown]
# ### Analysis of Bugs and Network Architecture

# %%
def get_tags(df):
    tags = [re.findall(r'<([^>]*)>', tag) for tag in df['Tags']]
    tag_counts = Counter([tag for sublist in tags for tag in sublist])

    # Sort tag counts in descending order
    sorted_counts = sorted(tag_counts.items(), key=lambda x: x[1], reverse=True)

    # Print sorted tag counts
    for tag, count in sorted_counts:
        print(f"{tag}: {count}")

# %%
get_tags(model_bugs)
# Out:
# python: 71
# pytorch: 69
# bert-language-model: 44
# tensorflow: 35
# huggingface-transformers: 28
# transformer-model: 25
# deep-learning: 23
# nlp: 19
# keras: 16
# attention-model: 13
# machine-learning: 11
# model: 10
# neural-network: 8
# keras-layer: 7
# python-3.x: 7
# language-model: 7
# layer: 6
# pre-trained-model: 6
# conv-neural-network: 5
# activation-function: 5
# tensor: 5
# huggingface-tokenizers: 5
# tf.keras: 4
# tensorflow-model-garden: 4
# roberta-language-model: 3
# numpy: 3
# tensorflow2.0: 3
# gpt-2: 3
# torch: 3
# matrix: 2
# model-fitting: 2
# text-classification: 2
# tpu: 2
# pandas: 2
# object-detection-api: 2
# tensorflow-lite: 2
# word-embedding: 2
# training-data: 2
# fairseq: 2
# lstm: 2
# torchscript: 2
# nvidia: 2
# multi-layer: 1
# loops: 1
# sequence-to-sequence: 1
# resnet: 1
# machine-learning-model: 1
# efficientnet: 1
# translation: 1
# opennmt: 1
# tensorflow-hub: 1
# normalization: 1
# valueerror: 1
# faster-rcnn: 1
# deeplab: 1
# adb: 1
# tensorflow-datasets: 1
# self-attention: 1
# google-colaboratory: 1
# predict: 1
# object-detection: 1
# image: 1
# android: 1
# yolo: 1
# darknet: 1
# multidimensional-array: 1
# tensorflow.js: 1
# onnx: 1
# vgg-net: 1
# seq2seq: 1
# conda: 1
# save: 1
# for-loop: 1
# sentiment-analysis: 1
# r: 1
# reticulate: 1
# computer-vision: 1
# time-series: 1
# c++: 1
# parameters: 1
# gcp-ai-platform-notebook: 1
# pytorch-dataloader: 1
# vision: 1
# pytorch-geometric: 1
# mask: 1
# embedding: 1
# autograd: 1
# gaussian-mixture-model: 1
# machine-translation: 1
# caffe: 1
# amazon-ec2: 1
# perplexity: 1
# tokenize: 1
# densenet: 1
# iris-dataset: 1

# %%
get_tags(tensor_bugs)
# Out:
# tensor: 204
# pytorch: 158
# python: 147
# tensorflow: 39
# numpy: 15
# deep-learning: 14
# torch: 12
# machine-learning: 11
# tensorflow2.0: 9
# indexing: 9
# javascript: 6
# tensorflow.js: 6
# neural-network: 6
# arrays: 6
# gpu: 5
# python-3.x: 4
# conv-neural-network: 4
# concatenation: 4
# tensorflow-datasets: 4
# multidimensional-array: 4
# vectorization: 4
# dimensions: 3
# list: 3
# slice: 3
# sorting: 3
# keras: 2
# array-broadcasting: 2
# matrix-multiplication: 2
# pandas: 2
# ragged: 2
# node.js: 2
# ragged-tensors: 2
# image: 2
# bert-language-model: 2
# torchvision: 2
# reshape: 2
# linear-algebra: 2
# image-processing: 2
# matrix: 2
# derivative: 2
# dynamic-programming: 2
# opencv: 1
# flutter: 1
# dart: 1
# random-seed: 1
# shapes: 1
# max-pooling: 1
# if-statement: 1
# optimization: 1
# output: 1
# word-embedding: 1
# tensorflow2.x: 1
# angular: 1
# tensorflowjs-converter: 1
# object-detection: 1
# layer: 1
# multiplication: 1
# metrics: 1
# pearson-correlation: 1
# module: 1
# loops: 1
# type-conversion: 1
# reduce: 1
# cpu: 1
# react-native: 1
# google-colaboratory: 1
# scalar: 1
# syntax: 1
# difference: 1
# image-segmentation: 1
# diagonal: 1
# index-error: 1
# mask: 1
# matrix-indexing: 1
# scikit-learn: 1
# fast-ai: 1
# precision: 1
# casting: 1
# autoencoder: 1
# numpy-ndarray: 1
# unfold: 1
# advanced-indexing: 1
# iteration: 1
# processing-efficiency: 1
# data-manipulation: 1
# pairwise: 1
# fairseq: 1
# zero-padding: 1
# argmax: 1
# libtorch: 1
# numpy-einsum: 1
# convolution: 1
# nlp: 1
# motion-blur: 1
# matplotlib: 1
# activation-function: 1
# memory: 1
# computer-vision: 1
# gradient: 1
# scipy: 1
# tsne: 1
# tpu: 1
# broadcast: 1
# normalization: 1
# mnist: 1
# backpropagation: 1
# reverse: 1
# model: 1
# lstm: 1
# dataframe: 1
# dtype: 1
# for-loop: 1
# tensordot: 1
# numpy-slicing: 1
# rounding: 1
# indices: 1
# nvidia: 1
# resnet: 1

# %%
get_tags(training_bugs)
# Out:
# python: 63
# pytorch: 61
# loss-function: 40
# tensorflow: 30
# optimization: 20
# deep-learning: 19
# neural-network: 17
# machine-learning: 14
# training-data: 11
# keras: 10
# performance: 10
# data-augmentation: 9
# conv-neural-network: 6
# nan: 6
# loss: 4
# cross-entropy: 4
# tensorflow2.0: 3
# python-3.x: 3
# learning-rate: 3
# gradient: 2
# gpu: 2
# javascript: 2
# matrix-multiplication: 2
# image-segmentation: 2
# autoencoder: 2
# valueerror: 2
# classification: 2
# gradient-descent: 2
# validation: 2
# loops: 2
# huggingface-transformers: 2
# pytorch-lightning: 2
# mse: 2
# sgd: 2
# r: 1
# lstm: 1
# missing-data: 1
# weighted: 1
# coefficients: 1
# data-generation: 1
# hyperparameters: 1
# rasa-nlu: 1
# rasa: 1
# tpu: 1
# tensorflow-datasets: 1
# image-rotation: 1
# conv1d: 1
# if-statement: 1
# tensor: 1
# semantic-segmentation: 1
# imbalanced-data: 1
# image-processing: 1
# google-colaboratory: 1
# checkpoint: 1
# data-preprocessing: 1
# image-masking: 1
# tensorflow.js: 1
# nonlinear-optimization: 1
# memory: 1
# tensorboard: 1
# arrays: 1
# numpy: 1
# intel-mkl: 1
# vgg-net: 1
# model-fitting: 1
# filtering: 1
# probability: 1
# plot: 1
# mean-square-error: 1
# transfer-learning: 1
# autograd: 1
# recurrent-neural-network: 1
# jax: 1
# backpropagation: 1
# automatic-differentiation: 1
# affinetransform: 1
# torchvision: 1
# artificial-intelligence: 1
# mini-batch: 1
# custom-training: 1
# image-formats: 1
# initialization: 1
# normalization: 1
# softmax: 1
# intel: 1
# intel-python: 1
# intel-pytorch: 1
# runtime: 1
# dnn9: 1
# faster-rcnn: 1
# speech-recognition: 1
# conda: 1
# importerror: 1
# model: 1
# pytorch-geometric: 1
# mathematical-optimization: 1
# torch: 1
# nlp: 1
# for-loop: 1
# graph: 1
# computer-vision: 1

# %%
get_tags(gpu_bugs)
# Out:
# gpu: 72
# tensorflow: 55
# pytorch: 52
# python: 48
# nvidia: 20
# cuda: 20
# tensorflow2.0: 10
# deep-learning: 7
# cudnn: 5
# docker: 5
# tensor: 5
# python-3.x: 4
# out-of-memory: 4
# conda: 4
# tensorrt: 3
# ubuntu: 3
# multi-gpu: 3
# c++: 3
# nvcc: 3
# pytorch-lightning: 3
# google-cloud-platform: 2
# driver: 2
# nvidia-jetson: 2
# slurm: 2
# anaconda: 2
# nvidia-docker: 2
# distributed-computing: 2
# cpu: 2
# conv-neural-network: 2
# neural-network: 2
# ubuntu-18.04: 1
# jupyter-notebook: 1
# blas: 1
# google-dl-platform: 1
# linux: 1
# time: 1
# startup: 1
# rtx: 1
# onnx: 1
# tensorflow-federated: 1
# training-data: 1
# tpu: 1
# reinforcement-learning: 1
# installation: 1
# gdb: 1
# cuda-gdb: 1
# performance: 1
# matrix-multiplication: 1
# ubuntu-20.04: 1
# tfx: 1
# tritonserver: 1
# gradienttape: 1
# hpc: 1
# lib: 1
# yolo: 1
# module: 1
# ssh: 1
# paramiko: 1
# artificial-intelligence: 1
# miniconda: 1
# dcgan: 1
# multiple-gpu: 1
# parallel-processing: 1
# nvidia-jetson-nano: 1
# tensorboard: 1
# javascript: 1
# tensorflow.js: 1
# docker-compose: 1
# dataloader: 1
# ddp: 1
# opencl: 1
# compiler-errors: 1
# debugging: 1
# autoencoder: 1
# numpy: 1
# apex: 1
# torch: 1
# machine-learning: 1
# cuda-streams: 1
# numba: 1
# yolov5: 1
# memory: 1
# nvidia-smi: 1
# vram: 1
# dimensions: 1
# model: 1
# bert-language-model: 1
# huggingface-transformers: 1
# gcp-ai-platform-notebook: 1
# python-poetry: 1
# pytorch-geometric: 1
# lstm: 1
# gcc: 1
# inference: 1
# libtorch: 1
# cmake: 1

# %%
get_tags(api_bugs)
# Out:
# python: 17
# pytorch: 11
# valueerror: 10
# tensorflow: 9
# typeerror: 8
# keras: 6
# attributeerror: 6
# python-3.x: 5
# google-colaboratory: 3
# importerror: 3
# generative-adversarial-network: 3
# numpy: 2
# deep-learning: 2
# huggingface-transformers: 2
# tensorflow-federated: 2
# optimization: 2
# modulenotfounderror: 1
# neural-network: 1
# relu: 1
# error-handling: 1
# efficientnet: 1
# tf.keras: 1
# precision-recall: 1
# dimensions: 1
# gpt-2: 1
# pycharm: 1
# windows-10: 1
# tensorflow2.0: 1
# loss-function: 1
# bert-language-model: 1
# multilabel-classification: 1
# chatbot: 1
# federated-learning: 1
# string: 1
# machine-learning: 1
# pytorch-dataloader: 1
# torch: 1
# fast-ai: 1
# sgd: 1
# conda: 1
# monk: 1
# retinanet: 1
# resuming-training: 1
# oop: 1
# tensorboard: 1
# densenet: 1

# %%
mixed_bugs = pd.concat([model_tensor, model_training, model_gpu, model_api, tensor_training, tensor_gpu, tensor_api, training_gpu, training_api, gpu_api], ignore_index=True)
get_tags(mixed_bugs)
# Out:
# pytorch: 12
# python: 11
# tensor: 11
# tensorflow: 7
# gpu: 7
# deep-learning: 5
# bert-language-model: 4
# model: 3
# training-data: 3
# nvidia: 3
# valueerror: 3
# optimization: 3
# javascript: 2
# tensorflow2.0: 2
# neural-network: 1
# layer: 1
# fairseq: 1
# activation-function: 1
# lstm: 1
# vgg-net: 1
# model-fitting: 1
# pytorch-geometric: 1
# huggingface-transformers: 1
# gcp-ai-platform-notebook: 1
# if-statement: 1
# module: 1
# cpu: 1
# tensorflow.js: 1
# dimensions: 1
# tpu: 1
# performance: 1
# matrix-multiplication: 1
# python-3.x: 1
# loss-function: 1
# sgd: 1
# conda: 1
# importerror: 1
